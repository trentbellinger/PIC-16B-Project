# %%
import pandas as pd
import re
import string
from datetime import datetime
import plotly.express as px
import string
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import inspect
warnings.filterwarnings('ignore')

# %%
from my_functions import clean_data, add_zero
print(inspect.getsource(clean_data))
# Out:
# def clean_data(df):
#
#     # Get rid of cancelled flights
#     df = df[df['CANCELLED'] == 0]
#     df = df[df['ARR_TIME'].notna() & df['ARR_DELAY'].notna()]
#     # Deal with NA's
#     df.fillna(0, inplace=True)
#
#     # Assign target outcome
#     df['target'] = (df['ARR_DELAY'] > 0).astype(int)
#
#     # only keep >750 flights
#     origin_counts = df.groupby('ORIGIN').size().reset_index(name='counts')
#     df = df.merge(origin_counts, on='ORIGIN', how='left')
#     df = df[df['counts']> 750]
#
#     # Convert Time
#     df.loc[:, 'DEP_TIME'] = df['DEP_TIME'].astype(int).astype(str)
#     df.loc[:,'DEP_TIME'] = df['DEP_TIME'].apply(add_zero)
#     df.loc[:,'DEP_TIME'] = df['DEP_TIME'].str.slice(start=0, stop=-2) + ':' + df['DEP_TIME'].str.slice(start=-2)
#     df.loc[:,'DEP_TIME'] = df['DEP_TIME'].apply(lambda x: '00' + x[2:] if x.startswith('24') else x)
#     df.loc[:,'DEP_TIME'] = pd.to_datetime(df['DEP_TIME'], format='%H:%M').dt.time
# ...

# %%
##airport = pd.read_csv("./Data/L_AIRPORT.csv")
#state_fips = pd.read_csv("./Data/L_STATE_FIPS.csv")
#wac = pd.read_csv("./Data/L_WORLD_AREA_CODES.csv")
air_jan23 =pd.read_csv("./Data/air_jan23.csv")
air_feb23 = pd.read_csv("./Data/air_feb23.csv")
air_mar23 = pd.read_csv("./Data/air_mar23.csv")
air_apr23 = pd.read_csv("./Data/air_apr23.csv")
air_may23 = pd.read_csv("./Data/air_may23.csv")
air_jun23 = pd.read_csv("./Data/air_jun23.csv")
air_jul23 = pd.read_csv("./Data/air_jul23.csv")
air_aug23 = pd.read_csv("./Data/air_aug23.csv")
air_sep23 = pd.read_csv("./Data/air_sep23.csv")
air_oct23 = pd.read_csv("./Data/air_oct23.csv")
air_nov23 = pd.read_csv("./Data/air_nov23.csv")

# %%
air_dec22 = pd.read_csv("./Data/air_dec22.csv")

# %%
air_nov23 = clean_data(air_nov23)

# %%
air_2023.tail()
# Out:
#         YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK  \
# 598362  2023        4     11            30            4
# 598363  2023        4     11            30            4
# 598364  2023        4     11            30            4
# 598365  2023        4     11            30            4
# 598366  2023        4     11            30            4
#
#                        FL_DATE ORIGIN ORIGIN_STATE_ABR  ORIGIN_STATE_FIPS  \
# 598362  11/30/2023 12:00:00 AM    XNA               AR                  5
# 598363  11/30/2023 12:00:00 AM    XNA               AR                  5
# 598364  11/30/2023 12:00:00 AM    XNA               AR                  5
# 598365  11/30/2023 12:00:00 AM    XNA               AR                  5
# 598366  11/30/2023 12:00:00 AM    XNA               AR                  5
#
#         ORIGIN_WAC  ... NAS_DELAY SECURITY_DELAY  LATE_AIRCRAFT_DELAY  target  \
# 598362          71  ...       0.0            0.0                  0.0       0
# ...

# %%
air_jan23
# Out:
#         Unnamed: 0  YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK  \
# 0               12  2023        1      1             1            7
# 1               13  2023        1      1             1            7
# 2               14  2023        1      1             1            7
# 3               15  2023        1      1             1            7
# 4               16  2023        1      1             1            7
# ...            ...   ...      ...    ...           ...          ...
# 511216      561350  2023        1      1            31            2
# 511217      561351  2023        1      1            31            2
# 511218      561352  2023        1      1            31            2
# 511219      561353  2023        1      1            31            2
# 511220      561354  2023        1      1            31            2
#
#                       FL_DATE ORIGIN  ORIGIN_CITY_NAME ORIGIN_STATE_ABR  ...  \
# ...

# %%
air_2023 = pd.concat([air_jan23,air_feb23, air_mar23, air_apr23, air_may23, air_jun23, air_jul23, air_aug23, air_sep23, air_oct23, air_nov23],axis=0, join='inner')

# %%
air_2023
# Out:
#         YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK  \
# 0       2023        1      1             1            7
# 1       2023        1      1             1            7
# 2       2023        1      1             1            7
# 3       2023        1      1             1            7
# 4       2023        1      1             1            7
# ...      ...      ...    ...           ...          ...
# 598362  2023        4     11            30            4
# 598363  2023        4     11            30            4
# 598364  2023        4     11            30            4
# 598365  2023        4     11            30            4
# 598366  2023        4     11            30            4
#
#                        FL_DATE ORIGIN ORIGIN_STATE_ABR  ORIGIN_STATE_FIPS  \
# 0         1/1/2023 12:00:00 AM    ABQ               NM                 35
# 1         1/1/2023 12:00:00 AM    ABQ               NM                 35
# ...

# %%
len(air_jan23)+len(air_feb23)+len(air_mar23)+len(air_apr23)+len(air_may23)+len(air_jun23)+len(air_jul23)+len(air_aug23)+len(air_sep23)+len(air_oct23)+len(air_nov23)
# Out:
# 6013171

# %%
air_2023.tail()
# Out:
#         YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK  \
# 598362  2023        4     11            30            4
# 598363  2023        4     11            30            4
# 598364  2023        4     11            30            4
# 598365  2023        4     11            30            4
# 598366  2023        4     11            30            4
#
#                        FL_DATE ORIGIN ORIGIN_STATE_ABR  ORIGIN_STATE_FIPS  \
# 598362  11/30/2023 12:00:00 AM    XNA               AR                  5
# 598363  11/30/2023 12:00:00 AM    XNA               AR                  5
# 598364  11/30/2023 12:00:00 AM    XNA               AR                  5
# 598365  11/30/2023 12:00:00 AM    XNA               AR                  5
# 598366  11/30/2023 12:00:00 AM    XNA               AR                  5
#
#         ORIGIN_WAC  ... NAS_DELAY SECURITY_DELAY  LATE_AIRCRAFT_DELAY  target  \
# 598362          71  ...       0.0            0.0                  0.0       0
# ...

# %% [markdown]
# ### Only keep >750 flights

# %%
air_jan23.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 511221 entries, 12 to 561354
# Data columns (total 48 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   YEAR                 511221 non-null  int64
#  1   QUARTER              511221 non-null  int64
#  2   MONTH                511221 non-null  int64
#  3   DAY_OF_MONTH         511221 non-null  int64
#  4   DAY_OF_WEEK          511221 non-null  int64
#  5   FL_DATE              511221 non-null  object
#  6   ORIGIN               511221 non-null  object
#  7   ORIGIN_CITY_NAME     511221 non-null  object
#  8   ORIGIN_STATE_ABR     511221 non-null  object
#  9   ORIGIN_STATE_FIPS    511221 non-null  int64
#  10  ORIGIN_STATE_NM      511221 non-null  object
#  11  ORIGIN_WAC           511221 non-null  int64
#  12  DEST                 511221 non-null  object
#  13  DEST_CITY_NAME       511221 non-null  object
#  14  DEST_STATE_ABR       511221 non-null  object
# ...

# %% [markdown]
# ### Read to csv

# %%
air_feb23.to_csv('./Data/air_feb23.csv')

# %%
air_jan23.to_csv('./Data/air_jan23.csv')

# %%
air_mar23.to_csv('./Data/air_mar23.csv')

# %%
air_apr23.to_csv('./Data/air_apr23.csv')

# %%
air_may23.to_csv('./Data/air_may23.csv')

# %%
air_jun23.to_csv('./Data/air_jun23.csv')

# %%
air_jul23.to_csv('./Data/air_jul23.csv')

# %%
air_aug23.to_csv('./Data/air_aug23.csv')

# %%
air_sep23.to_csv('./Data/air_sep23.csv')

# %%
air_oct23.to_csv('./Data/air_oct23.csv')

# %%
air_nov23.to_csv('./Data/air_nov23.csv')

# %%
air_2023.to_csv('./Data/air_2023.csv')
